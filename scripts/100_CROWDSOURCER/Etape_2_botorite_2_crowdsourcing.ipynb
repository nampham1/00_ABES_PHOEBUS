# %%
from webbot import Browser
from selenium import webdriver
import time
import json
import pandas as pd
import requests
from bs4 import BeautifulSoup
from unidecode import unidecode
import csv
from datetime import datetime

# %% [markdown]
# ## ETAPE 1 : SE CONNECTER A ATOM

# %%
def access_atom(driver):
    """
    Accède à la plateforme Phoebus en utilisant un objet de navigateur.

    Cette fonction effectue les étapes suivantes :
    1. Navigue vers la page d'accueil de Atom Archives.
    2. Clique sur le bouton "Ouverture de session".
    3. Utilise les identifiants stockés dans le fichier 'credentials.json' pour se connecter.

    Args:
        driver: Objet de navigateur permettant d'automatiser les interactions avec la page web.
    Note:
        Assurez-vous d'avoir un fichier 'credentials.json' contenant les champs 'email' et 'password'
        pour effectuer la connexion à Phoebus.
    """
        
    driver.go_to('https://atom-archives.unil.ch/index.php')
    driver.click('Ouverture de session', tag='button')
    
    with open('credentials.json', 'r') as jsonFile:
        credentials = json.load(jsonFile)
        
    driver.type(credentials['email'], id='email')
    driver.type(credentials['password'], id='password')
    driver.click('Ouverture de session')

# LANCEMENT DE LA FONCTION
driver = Browser() #Browser pour ouvrir un navigateur
access_atom(driver)

# %% [markdown]
# ## ETAPE 2 : ACQUISITION DES DONNEES

# %%
def extract_autorite(csv_path):
    """
    Extrait les noms à partir du fichier CSV contenant les noms et les données récupérées.
    Args:
        csv_path (str): Chemin vers le fichier CSV contenant les données récupérées.

    Returns:
        autorities (list): Liste des données récupérées.
    """
    
    # Charger le fichier CSV
    csv_path = '01_noticesACompleter.csv'
    df = pd.read_csv(csv_path, na_values=['NULL'], delimiter=',') #delimiter dépend de la configuration du separator du csv
    

    # Extraire les noms de la colonne "autoritesPHOEBUS"
    autorities = df.values.tolist()

    return autorities
    
# LANCEMENT DE LA FONCTION
csv_path = '01_noticesACompleter.csv'
autorities = extract_autorite(csv_path)
# Afficher les noms (à titre de vérification)
print(autorities)
# Out:
# [['ABRIQUET Evelyne', 1, 'https://atom-archives.unil.ch/index.php/abriquet-evelyne', nan, nan, nan, nan], ['ABRIQUET Michèle', 1, 'https://atom-archives.unil.ch/index.php/abriquet-michele', nan, nan, nan, nan], ['ACHTONI Marc', 1, 'https://atom-archives.unil.ch/index.php/achtoni-marc', nan, nan, nan, nan], ['AEBISCHER Jean-Marie', 1, 'https://atom-archives.unil.ch/index.php/aebischer-jean-marie', nan, nan, nan, nan], ['AEGATA Isabelle', 1, 'https://atom-archives.unil.ch/index.php/aegata-isabelle', nan, nan, nan, nan], ['AGUET Pierre', 1, 'https://atom-archives.unil.ch/index.php/aguet-pierre', nan, nan, nan, nan], ['ALAMHAS Emmanuelle', 1, 'https://atom-archives.unil.ch/index.php/alamhas-emmanuelle', nan, nan, nan, nan], ['ALFF Wilhelm', 1, 'https://atom-archives.unil.ch/index.php/alff-wilhelm', nan, nan, nan, nan], ['ALLAZ Bernard', 1, 'https://atom-archives.unil.ch/index.php/allaz-bernard', nan, nan, nan, nan], ['ALTENDORF Wolfgang', 1, 'https://atom-archives.unil.ch/index.php/altendorf
# %% [markdown]
# ## ETAPE 3 : ENTRER DANS LA NOTICE EN MODE EDITION

# %%
def open_autorites(csv_path):
    """
    Charge un fichier CSV, ajoute le suffixe "/edit#identityArea" à toutes les valeurs de la colonne "url_phoebus",
    puis extrait les noms modifiés de la colonne "url_phoebus".

    Args:
        csv_path (str): Chemin du fichier CSV.
    Returns:
        list: Liste des URLs renvoyant à l'édition des notices d'autorité, ouverte sur la Zone d'identification.
    """

    # Charger le fichier CSV
    df = pd.read_csv(csv_path, delimiter=',') #delimiter dépend de la configuration du separator du csv

    # Extraire les noms de la colonne "url_phoebus" et ajouter le suffixe "/edit#identityArea" à toutes les valeurs de la colonne "url_phoebus" 
    df['url_phoebus'] = df['url_phoebus'].astype(str) + '/edit#identityArea'

    # Extraire les noms de la colonne "notice 1" modifiée
    autorites_url = df['url_phoebus'].tolist()
    
    return autorites_url

# LANCEMENT DE LA FONCTION
csv_path = '01_noticesACompleter.csv'
autorites_url = open_autorites(csv_path)
print(autorites_url)
# Out:
# ['https://atom-archives.unil.ch/index.php/abriquet-evelyne/edit#identityArea', 'https://atom-archives.unil.ch/index.php/abriquet-michele/edit#identityArea', 'https://atom-archives.unil.ch/index.php/achtoni-marc/edit#identityArea', 'https://atom-archives.unil.ch/index.php/aebischer-jean-marie/edit#identityArea', 'https://atom-archives.unil.ch/index.php/aegata-isabelle/edit#identityArea', 'https://atom-archives.unil.ch/index.php/aguet-pierre/edit#identityArea', 'https://atom-archives.unil.ch/index.php/alamhas-emmanuelle/edit#identityArea', 'https://atom-archives.unil.ch/index.php/alff-wilhelm/edit#identityArea', 'https://atom-archives.unil.ch/index.php/allaz-bernard/edit#identityArea', 'https://atom-archives.unil.ch/index.php/altendorf-wolfgang/edit#identityArea', 'https://atom-archives.unil.ch/index.php/altwegg-jurg/edit#identityArea', 'https://atom-archives.unil.ch/index.php/amaudruz-gaston-armand/edit#identityArea', 'https://atom-archives.unil.ch/index.php/ambuhl-jacques/edit#identityArea', 'https://atom-archives.unil.ch/index.php/amstutz-betty/edit#identityArea', 'https://atom-archives.unil.ch/index.php/amstutz-patrick/edit#identityArea', 'https://atom-archives.unil.ch/index.php/amy-laurence/edit#identityArea', 'https://atom-archives.unil.ch/index.php/anceschi-luciano/edit#identityArea', 'https://atom-archives.unil.ch/index.php/andre-paul/edit#identityArea', 'https://atom-archives.unil.ch/index.php/anet-helga/edit#identityArea', 'https://atom-archives.unil.ch/index.php/angjelinovic-danko/edit#identityArea', 'https://atom-archives.unil.ch/index.php/ansermot-bernard/edit#identityArea', 'https://atom-archives.unil.ch/index.php/ansermoz-felix/edit#identityArea', 'https://atom-archives.unil.ch/index.php/appia-blach-beatrice/edit#identityArea', 'https://atom-archives.unil.ch/index.php/arionesco-galina/edit#identityArea', 'https://atom-archives.unil.ch/index.php/arnaud-jean-claude/edit#identityArea', 'https://atom-archives.unil.ch/index.php/arnold-pierre/edit#identityArea', 'https://atom-archives.unil.ch/index.php/assad-frederic/edit#identityArea', 'https://atom-archives.unil.ch/index.php/assal-frederic/edit#identityArea', 'https://atom-archives.unil.ch/index.php/aubert-michel/edit#identityArea', 'https://atom-archives.unil.ch/index.php/aubert-raphael/edit#identityArea', 'https://atom-archives.unil.ch/index.php/aubert-roger/edit#identityArea', 'https://atom-archives.unil.ch/index.php/aubry-anne-marie/edit#identityArea', 'https://atom-archives.unil.ch/index.php/auchelin-antoine/edit#identityArea', 'https://atom-archives.unil.ch/index.php/auchincloss-louis/edit#identityArea', 'https://atom-archives.unil.ch/index.php/ausseil-gilberte/edit#identityArea', 'https://atom-archives.unil.ch/index.php/avenay-lucie/edit#identityArea', 'https://atom-archives.unil.ch/index.php/avvanzino-pierre/edit#identityArea', 'https://atom-archives.unil.ch/index.php/aziz-bouajila/edit#identityArea', 'https://atom-archives.unil.ch/index.php/bachmann-ina/edit#identityArea', 'https://atom-archives.unil.ch/index.php/bacsy-judith/edit#identityArea', 'https://atom-archives.unil.ch/index.php/badoux-eugene/edit#identityArea', 'https://atom-archives.unil.ch/index.php/badoux-lisette/edit#identityArea', 'https://atom-archives.unil.ch/index.php/badoux-nicole/edit#identityArea', 'https://atom-archives.unil.ch/index.php/balitzer-helene/edit#identityArea', 'https://atom-archives.unil.ch/index.php/barbey-alice/edit#identityArea', 'https://atom-archives.unil.ch/index.php/barbey-leon/edit#identityArea', 'https://atom-archives.unil.ch/index.php/barbezat-alice/edit#identityArea', 'https://atom-archives.unil.ch/index.php/barjavel-rene/edit#identityArea', 'https://atom-archives.unil.ch/index.php/bartholdi-jean/edit#identityArea', 'https://atom-archives.unil.ch/index.php/bartolomeo-joelle/edit#identityArea', 'https://atom-archives.unil.ch/index.php/bauchau-henri/edit#identityArea', 'https://atom-archives.unil.ch/index.php/baud-monique/edit#identityArea', 'https://atom-archives.uni ...

# %% [markdown]
# ## ETAPE 4 : OUVRIR LES ZONES ET SAISIR LES INFORMATIONS

# %%
def modify_autorites (driver, autorities, autorites_url):
    """
    MOdification et correction en série, ajout de la mention crowdsourcing"

    Cette fonction prend un objet 'driver' pour la navigation web automatisée, une liste d'autorités
    récupérées depuis IdRef, et une liste d'URLs pour les notices d'autorité. Elle ouvre chaque notice d'autorité
    avec le navigateur automatisé, ouvre toutes les Zones, saisit les informations appropriées dans les champs correspondants,
    et sauvegarde les modifications.

    Args:
        driver: Objet pour la navigation web automatisée.
        autorities (list): Liste d'autorités récupérées depuis IdRef.
        autorites_url (list): Liste d'URLs pour les notices d'autorité.

    Returns:
        None
    Notes :
        La fonction inclut les modifications automatiques effectuées par Botorité.
    """   
    try:
        
        for i, autorite_url in enumerate(autorites_url) :
            
            driver.go_to(autorite_url)

            # Ouvrir toutes les Zones
            driver.click('Zone du contrôle')   
            driver.execute_script("window.scrollTo(0,0);")
            time.sleep(2)
            driver.click('Zone de description')
            
            # Récupérer le contenu HTML depuis la page
            content = driver.get_page_source()
            soup = BeautifulSoup(content, features='lxml')
            time.sleep(2)

                
            ## ZONE DESCRIPTION

            # Modification du type d'entité
            driver.click(tag='select', id='entityType')
            driver.click('Personne', tag='option')

            #Date
            if driver.exists(id='datesOfExistence'):
                 # Trouver l'élément par son ID à l'aide de BeautifulSoup
                existence_element = soup.find(id='datesOfExistence')
                if existence_element:
                    existence_value = existence_element.get('value', '')
                    # Vérifier si la valeur est vide ou "n.c."
                    if existence_value == "" :
                        # Si la valeur est vide ou "n.c.", saisir "s.d."
                        driver.type("s.d.", id='datesOfExistence')
                    else:
                        # Sinon, saisir la valeur existante
                        driver.type(existence_value, id='datesOfExistence')
            else:
                print(f"ERREUR pour {autorities[i][1]} : Dates d'existence n'ont pas été trouvées et saisies")

            #Historique
            
            crowdsourcing_value = "**Production participative [*crowdsourcing*]** : Si vous possédez des informations sur cette personne, notamment les dates de naissance et de décès, ainsi que des éléments biographiques, veuillez nous contacter à [clsr@unil.ch](mailto:clsr@unil.ch?subject=[crowdsourcing])."
            if driver.exists(id='history'):
                
                history_element = soup.find(id='history')
                if history_element:
                    
                    history_value = history_element.get('value','')
                    
                    if history_value == "":
                        driver.type(crowdsourcing_value, id='history')
                    else:
                        driver.type(history_value, id='history')
            else:
                print(f"ERREUR pour {autorities[i][1]} : Historique n'a pas été trouvée et saisie")  
                                        
            time.sleep(1)
            
            ## ZONE DE CONTROLE

            # saisie de l'identifiant basé sur l'url
            
            identifiant_url = autorites_url[i]
            identifiant_url = identifiant_url.replace("https://atom-archives.unil.ch/index.php/", "").replace("/edit#identityArea", "")
        
            if driver.exists(id='descriptionIdentifier'):
                
                driver.type(identifiant_url, id='descriptionIdentifier')
            else:
                print(f"ERREUR pour {autorities[i][1]} : Identifiant de la description n'a pas été trouvée et saisie")
            
            # Modification de l'entretien du dépôt
            if driver.exists(id='maintainingRepository'):
                driver.type('Centre des littératures en Suisse romande', id='maintainingRepository')
                time.sleep(4)
                driver.press(driver.Key.ENTER)
            else:
                print(f"ERREUR pour {autorities[i][1]} : Entretien du dépôt de la description n'a pas été trouvé et saisi")
            
                       
            # Modification du statut
            driver.click(tag='select', id='descriptionStatus')
            driver.click('Ébauche', tag='option')
            
            # Notes de maintenance            
            today_date = datetime.today().strftime('%Y-%m-%d à %H:%M:%S')
            maintenance_text = f"""Saisie automatique [L04] effectuée le : """ + today_date
            if driver.exists(id='maintenanceNotes'):
                driver.type(maintenance_text, id='maintenanceNotes')
            else:
                print(f"ERREUR pour {autorities[i][1]} : Notes de maintenance n'ont pas été trouvées et saisies")
      
                
            # scroller vers le bas puis, sauvegarder la saisie
            driver.execute_script("window.scrollTo(0,document.body.scrollHeight)")
            time.sleep(2)

            driver.click('Sauvegarder', tag='input')
            
            print(f"({i+1}) Opération de saisie terminée pour {autorities[i][1]} : {autorities[i][0]}")
        
    except Exception as e:
        print(f"Etape 9 : Erreur lors de la modification des notices d'autorité : {e}")
        
# LANCEMENT DE LA FONCTION        
modify_autorites(driver, autorities, autorites_url)
# Out:
# (1) Opération de saisie terminée pour 1 : ABRIQUET Evelyne
# (2) Opération de saisie terminée pour 1 : ABRIQUET Michèle
# (3) Opération de saisie terminée pour 1 : ACHTONI Marc
# (4) Opération de saisie terminée pour 1 : AEBISCHER Jean-Marie
# (5) Opération de saisie terminée pour 1 : AEGATA Isabelle
# (6) Opération de saisie terminée pour 1 : AGUET Pierre
# (7) Opération de saisie terminée pour 1 : ALAMHAS Emmanuelle
# (8) Opération de saisie terminée pour 1 : ALFF Wilhelm
# (9) Opération de saisie terminée pour 1 : ALLAZ Bernard
# (10) Opération de saisie terminée pour 1 : ALTENDORF Wolfgang
# (11) Opération de saisie terminée pour 1 : ALTWEGG Jurg
# (12) Opération de saisie terminée pour 1 : AMAUDRUZ Gaston-Armand
# (13) Opération de saisie terminée pour 1 : AMBÜHL Jacques
# (14) Opération de saisie terminée pour 1 : AMSTUTZ Betty
# (15) Opération de saisie terminée pour 1 : AMSTUTZ Patrick
# (16) Opération de saisie terminée pour 1 : AMY Laurence
# (17) Opération de saisie terminée pour 1 : ANCESCHI Luciano
# (18) Opération de saisie terminée pour 1 : ANDRÉ Paul
# (19) Opération de saisie terminée pour 1 : ANET Helga
# (20) Opération de saisie terminée pour 1 : ANGJELINOVIC Danko
# (21) Opération de saisie terminée pour 1 : ANSERMOT Bernard
# (22) Opération de saisie terminée pour 1 : ANSERMOZ Félix
# (23) Opération de saisie terminée pour 1 : APPIA Blach Béatrice
# (24) Opération de saisie terminée pour 1 : ARIONESCO Galina
# (25) Opération de saisie terminée pour 1 : ARNAUD Jean-Claude
# (26) Opération de saisie terminée pour 1 : ARNOLD Pierre
# (27) Opération de saisie terminée pour 1 : ASSAD Frédéric
# (28) Opération de saisie terminée pour 1 : ASSAL Frédéric
# (29) Opération de saisie terminée pour 1 : AUBERT Michel
# (30) Opération de saisie terminée pour 1 : AUBERT Raphaël
# (31) Opération de saisie terminée pour 1 : AUBERT Roger
# (32) Opération de saisie terminée pour 1 : AUBRY Anne-Marie
# (33) Opération de saisie terminée pour 1 : AUCHELIN Antoine
# (34) Opération de saisie terminée pour 1 : AUCHINCLOSS Louis
# (35) Opération de saisie terminée pour 1 : AUSSEIL Gilberte
# (36) Opération de saisie terminée pour 1 : AVENAY Lucie
# (37) Opération de saisie terminée pour 1 : AVVANZINO Pierre
# (38) Opération de saisie terminée pour 1 : AZIZ Bouajila
# (39) Opération de saisie terminée pour 1 : BACHMANN Ina
# (40) Opération de saisie terminée pour 1 : BACSY Judith
# (41) Opération de saisie terminée pour 1 : BADOUX Eugène
# (42) Opération de saisie terminée pour 1 : BADOUX Lisette
# (43) Opération de saisie terminée pour 1 : BADOUX Nicole
# (44) Opération de saisie terminée pour 1 : BALITZER Hélène
# (193) Opération de saisie terminée pour 1 : CONTAT Jérémy
# (194) Opération de saisie terminée pour 1 : CONTINI Ennio
# (195) Opération de saisie terminée pour 1 : CONTINI Mariuccia
# (196) Opération de saisie terminée pour 1 : COQUERAND Marcel
# (197) Opération de saisie terminée pour 1 : COQUOZ Didier
# (198) Opération de saisie terminée pour 1 : CORBAZ Simone
# (199) Opération de saisie terminée pour 1 : CORMINBOEUF Jean
# (200) Opération de saisie terminée pour 1 : CORNIL Gaston
# (201) Opération de saisie terminée pour 1 : CORNSOZ François
# (202) Opération de saisie terminée pour 1 : CORNUZ Aline Alphonsine
# (203) Opération de saisie terminée pour 1 : CORNUZ Catherine
# (204) Opération de saisie terminée pour 1 : CORNUZ Charles
# (205) Opération de saisie terminée pour 1 : CORNUZ Christiane
# (206) Opération de saisie terminée pour 1 : CORPATAUC Nicole
# (207) Opération de saisie terminée pour 1 : CORTHÉSY Gaston
# (208) Opération de saisie terminée pour 1 : COSSETTO Angèle
# (209) Opération de saisie terminée pour 1 : COTTIER Anne-Claude
# (210) Opération de saisie terminée pour 1 : COTTIER Marius
# (211) Opération de saisie terminée pour 1 : COUTAZ Christian (Paradiso)
# (212) Opération de saisie terminée pour 1 : CRAUSAZ Irène
# (213) Opération de saisie terminée pour 1 : CRUCHET Roxane
# (214) Opération de saisie terminée pour 1 : CUDET Pierre
# (215) Opération de saisie terminée pour 1 : CUENDET Jean-Pierre
# (216) Opération de saisie terminée pour 1 : CUENDET Marguerite
# (217) Opération de saisie terminée pour 1 : CUENDET Viviane
# (218) Opération de saisie terminée pour 1 : DAILLIE René-François
# (219) Opération de saisie terminée pour 1 : DAUMÜLLER Stefanie
# (220) Opération de saisie terminée pour 1 : DE KEUSTER Andrée
# (221) Opération de saisie terminée pour 1 : DEBÉTAZ Géo
# (222) Opération de saisie terminée pour 1 : DEGAL Simone
# (223) Opération de saisie terminée pour 1 : DEKESTER Christiane
# (224) Opération de saisie terminée pour 1 : DELAY Sophie-Emile
# (225) Opération de saisie terminée pour 1 : DELSETH Claude
# (226) Opération de saisie terminée pour 1 : DEMELIN Claude
# (227) Opération de saisie terminée pour 1 : DEMIÉVILLE Pierre
# (228) Opération de saisie terminée pour 1 : DENAT Marie-Christine
# (229) Opération de saisie terminée pour 1 : DEOOLATO Philippe
# (230) Opération de saisie terminée pour 1 : DEPPIERRAZ Jean-François
# (231) Opération de saisie terminée pour 1 : DERONZIER Geneviève
# (232) Opération de saisie terminée pour 1 : DESCOEUDRES Eric
# (233) Opération de saisie terminée pour 1 : DEVAUD Jean
# (234) Opération de saisie terminée pour 1 : DIGOT Simone
# (235) Opération de saisie terminée pour 1 : DIMITROV Théodore
# (236) Opération de saisie terminée pour 1 : DREYFUSS Robert
# (237) Opération de saisie terminée pour 1 : DUBOIS Serge
# (238) Opération de saisie terminée pour 1 : DUBRUEL Marion
# (239) Opération de saisie terminée pour 1 : DUBUIS Jean-Néville
# (240) Opération de saisie terminée pour 1 : DUBUIS Samuel
# (241) Opération de saisie terminée pour 1 : DUBUIS Simon
# (242) Opération de saisie terminée pour 1 : DUDT Jean-Paul
# (243) Opération de saisie terminée pour 1 : DUFRESNE Germaine
# (244) Opération de saisie terminée pour 1 : DUMONT Michel
# (245) Opération de saisie terminée pour 1 : DUNAND Michel
# (246) Opération de saisie terminée pour 1 : DUNNER Jean
# (247) Opération de saisie terminée pour 1 : DUPASQUIER Elaine
# (248) Opération de saisie terminée pour 1 : DUPERRET Jacques
# (249) Opération de saisie terminée pour 1 : DUPERTUIS Christine
# (250) Opération de saisie terminée pour 1 : DUPRAZ André
# (251) Opération de saisie terminée pour 1 : DURAND Hyacinthe
# (252) Opération de saisie terminée pour 1 : DUROUX Rose
# (253) Opération de saisie terminée pour 1 : DURUSSEL Jean-François
# (254) Opération de saisie terminée pour 1 : DUTOIT Louison
# (255) Opération de saisie terminée pour 1 : DUTOIT Michel
# (256) Opération de saisie terminée pour 1 : EBERLI Oscar et Josette
# (257) Opération de saisie terminée pour 1 : EBNER Franz
# (258) Opération de saisie terminée pour 1 : ELAMARI-SUDAN Danielle
# (259) Opération de saisie terminée pour 1 : ELSNER Karl
# (260) Opération de saisie terminée pour 1 : EMERY François
# (261) Opération de saisie terminée pour 1 : ENCKELL Marianne
# (262) Opération de saisie terminée pour 1 : ESSENLINCK Jean
# (263) Opération de saisie terminée pour 1 : ESSINGER Diane
# (264) Opération de saisie terminée pour 1 : ESTOPPEY Ruth
# (265) Opération de saisie terminée pour 1 : FABBRI Casimiro
# (266) Opération de saisie terminée pour 1 : FABIAN Bob
# (267) Opération de saisie terminée pour 1 : FAES Edouard
# (268) Opération de saisie terminée pour 1 : FAGUE René
# (269) Opération de saisie terminée pour 1 : FAHRNI Danielle
# (270) Opération de saisie terminée pour 1 : FAILLETTAZ Jacques
# (271) Opération de saisie terminée pour 1 : FALLENIUS Kristina
# (272) Opération de saisie terminée pour 1 : FANTOLI Jean
# (273) Opération de saisie terminée pour 1 : FATIAN Robert
# (274) Opération de saisie terminée pour 1 : FATTA Franco
# (275) Opération de saisie terminée pour 1 : FATTEBERT Jean
# (276) Opération de saisie terminée pour 1 : FAUCHERRE Jean
# (277) Opération de saisie terminée pour 1 : FAUCHERRE-ETOT Anny
# (278) Opération de saisie terminée pour 1 : FAUCHEZ Pierre
# (279) Opération de saisie terminée pour 1 : FAUQUET Eric
# (280) Opération de saisie terminée pour 1 : FAVE Elisabeth
# (281) Opération de saisie terminée pour 1 : FAVRE Alain
# (282) Opération de saisie terminée pour 1 : FAVRE Charles
# (283) Opération de saisie terminée pour 1 : FAVRE Daniel
# (284) Opération de saisie terminée pour 1 : FAVRE Dominique
# (285) Opération de saisie terminée pour 1 : FAVRE Etienne
# (286) Opération de saisie terminée pour 1 : FAVRE Gabrielle
# (287) Opération de saisie terminée pour 1 : FAVRE Jean-Luc
# (288) Opération de saisie terminée pour 1 : FEIHL Albert-Olivier
# (289) Opération de saisie terminée pour 1 : FEIHL François
# (290) Opération de saisie terminée pour 1 : FEIHL Mireille
# (291) Opération de saisie terminée pour 1 : FEIHL Pierrette
# (292) Opération de saisie terminée pour 1 : FELIPE Pablo
# (293) Opération de saisie terminée pour 1 : FELITZ Ronald
# (294) Opération de saisie terminée pour 1 : FELIX Maurice
# (295) Opération de saisie terminée pour 1 : FELLAY Gerda
# (296) Opération de saisie terminée pour 1 : FENET Mathilde
# (297) Opération de saisie terminée pour 1 : FERRARI Arlette
# (298) Opération de saisie terminée pour 1 : FERRARI-CLÉMENT Josiane
# (299) Opération de saisie terminée pour 1 : FERRIÈRE Claude
# (300) Opération de saisie terminée pour 1 : FESCHOTTE Michèle
# (301) Opération de saisie terminée pour 1 : FIVAZ René
# (302) Opération de saisie terminée pour 1 : FLEURY Nicolas
# (303) Opération de saisie terminée pour 1 : FONTANET Guy
# (304) Opération de saisie terminée pour 1 : FONTANET-van HOLLEBEKE Paule
# (305) Opération de saisie terminée pour 1 : FONTANNAZ Philippe
# (306) Opération de saisie terminée pour 1 : FOREL René
# (307) Opération de saisie terminée pour 1 : FORESTIER George
# (308) Opération de saisie terminée pour 1 : FORESTIER Jean-Daniel
# (309) Opération de saisie terminée pour 1 : FORNEROD Serge
# (310) Opération de saisie terminée pour 1 : FORTIN Jean-Paul
# (311) Opération de saisie terminée pour 1 : FOSTER Jean-Claude
# (312) Opération de saisie terminée pour 1 : FRAI Alberto
# (313) Opération de saisie terminée pour 1 : FRANCEY Luc
# (314) Opération de saisie terminée pour 1 : FRANCIOLI Patrick
# (315) Opération de saisie terminée pour 1 : FRANCK Amélie
# (316) Opération de saisie terminée pour 1 : FRANCK Véronique
# (317) Opération de saisie terminée pour 1 : FREIHART Alex
# (318) Opération de saisie terminée pour 1 : FREIHOLZ Gilbert
# (319) Opération de saisie terminée pour 1 : FRESCHI Michele
# (320) Opération de saisie terminée pour 1 : FREYMOND Anne-Lise
# (321) Opération de saisie terminée pour 1 : FREYMOND Daniel
# (322) Opération de saisie terminée pour 1 : FROIDEVAUX Alain
# (323) Opération de saisie terminée pour 1 : FUCHS Rosemarie
# (324) Opération de saisie terminée pour 1 : FUMERO Graciliano Martín
# (325) Opération de saisie terminée pour 1 : FURCH Felix
# (326) Opération de saisie terminée pour 1 : GABELLA Eva
# (327) Opération de saisie terminée pour 1 : GABUS Michel
# (328) Opération de saisie terminée pour 1 : GAGNAUX Louis
# (329) Opération de saisie terminée pour 1 : GAIARDO Jorge
# (330) Opération de saisie terminée pour 1 : GAILLARD Martine
# (331) Opération de saisie terminée pour 1 : GAILLOUD François
# (332) Opération de saisie terminée pour 1 : GALEUCHET Agnès
# (333) Opération de saisie terminée pour 1 : GALLAY Marie
# (334) Opération de saisie terminée pour 1 : GALORTCHIMA Lora
# (335) Opération de saisie terminée pour 1 : GAMARRA Pierre
# (336) Opération de saisie terminée pour 1 : GARDIOL André
# (337) Opération de saisie terminée pour 1 : GARRIGUES Jean-Paul
# (338) Opération de saisie terminée pour 1 : GAULA Edward
# (339) Opération de saisie terminée pour 1 : GAUTHEY Henri
# (340) Opération de saisie terminée pour 1 : GAUTHIER Bernard-Claude
# (341) Opération de saisie terminée pour 1 : GAUTIER Jean-Claude
# (342) Opération de saisie terminée pour 1 : GAVILLET Jean-Michel
# (343) Opération de saisie terminée pour 1 : GAZZAR Daniel
# (344) Opération de saisie terminée pour 1 : GEERAERT Robert-Lucien
# (345) Opération de saisie terminée pour 1 : GEHRI Francine Charlotte
# (346) Opération de saisie terminée pour 1 : GEISENDORF-DESGOUTTES Théophile
# (347) Opération de saisie terminée pour 1 : GEISER Jacqueline
# (348) Opération de saisie terminée pour 1 : GELBERT Angela
# (349) Opération de saisie terminée pour 1 : GENEUX Laurent
# (350) Opération de saisie terminée pour 1 : GEORGES Maximilien
# (351) Opération de saisie terminée pour 1 : GERBER Gabrielle
# (352) Opération de saisie terminée pour 1 : GERBEX Robert
# (353) Opération de saisie terminée pour 1 : GERHARD Marie-Lise
# (354) Opération de saisie terminée pour 1 : GEX Nicolas
# (355) Opération de saisie terminée pour 1 : GIAMPICCOLI Franco
# (356) Opération de saisie terminée pour 1 : GIANADDA Léonard
# (357) Opération de saisie terminée pour 1 : GIBERT Jean
# (358) Opération de saisie terminée pour 1 : GIGON René
# (359) Opération de saisie terminée pour 1 : GILDEMEISTER Gisela
# (360) Opération de saisie terminée pour 1 : GILGEN Christiane
# (361) Opération de saisie terminée pour 1 : GILLIARD Knecht Marie-Claude
# (362) Opération de saisie terminée pour 1 : GILLIARD-MOSER Marie-Lise
# (363) Opération de saisie terminée pour 1 : GILLIÉRON Alain
# (364) Opération de saisie terminée pour 1 : GILLIÉRON Charles
# (365) Opération de saisie terminée pour 1 : GINET-SICAUD Marguerite
# (366) Opération de saisie terminée pour 1 : GINSBURG Theo
# (367) Opération de saisie terminée pour 1 : GIRARD-MONTET Gertrude
# (368) Opération de saisie terminée pour 1 : GIRARDET Daniel
# (369) Opération de saisie terminée pour 1 : GIRARDIN Benoit
# (370) Opération de saisie terminée pour 1 : GIROD Jean-Vital
# (371) Opération de saisie terminée pour 1 : CENTLIVRES Delphine
# (372) Opération de saisie terminée pour 1 : GLARDON Michel
# (373) Opération de saisie terminée pour 1 : GLARDON Pierre
# (374) Opération de saisie terminée pour 1 : GLATZ Georges
# (375) Opération de saisie terminée pour 1 : GLEYRE Francis
# (376) Opération de saisie terminée pour 1 : GOLAY Jean-Pierre
# (377) Opération de saisie terminée pour 1 : GOLAY Jean
# (378) Opération de saisie terminée pour 1 : GOLDFARB Mathilde
# (379) Opération de saisie terminée pour 1 : GOLDMAN Daniel
# (380) Opération de saisie terminée pour 1 : GONTHIER Alain
# (381) Opération de saisie terminée pour 1 : GONTHIER Albert
# (382) Opération de saisie terminée pour 1 : GONVERS Jean-Jacques
# (383) Opération de saisie terminée pour 1 : GOODSON Rodger
# (384) Opération de saisie terminée pour 1 : GORDON Edith
# (385) Opération de saisie terminée pour 1 : GOUTORBE Robert
# (485) Opération de saisie terminée pour 1 : JACQUAT Marcel S.
# (486) Opération de saisie terminée pour 1 : JACTET Mario
# (487) Opération de saisie terminée pour 1 : JAGGI Yvette
# (488) Opération de saisie terminée pour 1 : JALEY Gilbert
# (489) Opération de saisie terminée pour 1 : JAN Renée
# (490) Opération de saisie terminée pour 1 : JAN-DUIVEN Renée
# (491) Opération de saisie terminée pour 1 : JAQUES Françoise
# (492) Opération de saisie terminée pour 1 : JAQUES Philippe
# (493) Opération de saisie terminée pour 1 : JAQUET-BERGER Christiane (Conseil national)
# (494) Opération de saisie terminée pour 1 : JAQUILLARD Claude
# (495) Opération de saisie terminée pour 1 : JAUSLIN Jean-Frédéric
# (496) Opération de saisie terminée pour 1 : JAVET Pierre
# (497) Opération de saisie terminée pour 1 : JAY Roland
# (498) Opération de saisie terminée pour 1 : JEANNERET Pierre
# (499) Opération de saisie terminée pour 1 : JEANPRÊTRE Francine
# (500) Opération de saisie terminée pour 1 : JEMELIN Claude
# (501) Opération de saisie terminée pour 1 : JEMELIN Mireille
# (502) Opération de saisie terminée pour 1 : JEREMIJEW Michel
# (503) Opération de saisie terminée pour 1 : JOBIN Jean-François
# (504) Opération de saisie terminée pour 1 : JOLLIET Gilbert
# (505) Opération de saisie terminée pour 1 : JORAY Colette
# (506) Opération de saisie terminée pour 1 : JORAY Marcel
# (507) Opération de saisie terminée pour 1 : JOSEPH Gabriel
# (508) Opération de saisie terminée pour 1 : JUFER-BORLOZ André
# (509) Opération de saisie terminée pour 1 : JUILLARD Edouard (docteur)
# (510) Opération de saisie terminée pour 1 : JUILLERAT Pierre
# (511) Opération de saisie terminée pour 1 : JUILLERAT René
# (512) Opération de saisie terminée pour 1 : JULIS David
# (513) Opération de saisie terminée pour 1 : JUNOD Micheline
# (514) Opération de saisie terminée pour 1 : JUNOD Raymond
# (515) Opération de saisie terminée pour 1 : KAECH René
# (516) Opération de saisie terminée pour 1 : KAENEL Kaenel Johanna
# (517) Opération de saisie terminée pour 1 : KEENHARDY Ray
# (518) Opération de saisie terminée pour 1 : KELITH Muriel
# (519) Opération de saisie terminée pour 1 : KELLER Alois
# (520) Opération de saisie terminée pour 1 : KELLER Samuel
# (521) Opération de saisie terminée pour 1 : KEMP Robert
# (522) Opération de saisie terminée pour 1 : KERY Edith
# (523) Opération de saisie terminée pour 1 : KETTERER Claude
# (524) Opération de saisie terminée pour 1 : KIA-TCHANG Houang
# (525) Opération de saisie terminée pour 1 : KILCHER Michelle
# (526) Opération de saisie terminée pour 1 : KOCH Anne-Françoise
# (527) Opération de saisie terminée pour 1 : KOHLI Dominique
# (528) Opération de saisie terminée pour 1 : KOLB Guido
# (529) Opération de saisie terminée pour 1 : KONÉ Mary
# (530) Opération de saisie terminée pour 1 : KOSTIKOV Anatole
# (531) Opération de saisie terminée pour 1 : KOWALSKI Joseph
# (532) Opération de saisie terminée pour 1 : KRAFT Monique
# (533) Opération de saisie terminée pour 1 : KRÄHENBUHL Charles
# (534) Opération de saisie terminée pour 1 : KRICHNER Eliane
# (535) Opération de saisie terminée pour 1 : KULLS Leonard
# (536) Opération de saisie terminée pour 1 : KUNZ Jean-Claude
# (537) Opération de saisie terminée pour 1 : KUNZI René
# (538) Opération de saisie terminée pour 1 : KUTSCHLE Karl
# (539) Opération de saisie terminée pour 1 : LAMUNIÈRE Marc
# (540) Opération de saisie terminée pour 1 : LANG Claude
# (541) Opération de saisie terminée pour 1 : LANGLOIS Christian
# (542) Opération de saisie terminée pour 1 : LAPORTE André
# (543) Opération de saisie terminée pour 1 : LAPPE Isabelle
# (544) Opération de saisie terminée pour 1 : LASSERRE André
# (545) Opération de saisie terminée pour 1 : LAUFER Claude
# (546) Opération de saisie terminée pour 1 : LAURANO Renzo
# (547) Opération de saisie terminée pour 1 : LAURENT Luc
# (548) Opération de saisie terminée pour 1 : LAVANCHY Cécile
# (549) Opération de saisie terminée pour 1 : LAVANCHY Charles
# (550) Opération de saisie terminée pour 1 : LAVANCHY Georges
# (551) Opération de saisie terminée pour 1 : LAVANCHY Henri
# (552) Opération de saisie terminée pour 1 : LAVAUX Gérard
# (553) Opération de saisie terminée pour 1 : LAVEY Jean
# (554) Opération de saisie terminée pour 1 : LEBOISSARD Corinne
# (555) Opération de saisie terminée pour 1 : LECOULTRE Ferdinand et Françoise
# (556) Opération de saisie terminée pour 1 : LEDERREY Philippe
# (557) Opération de saisie terminée pour 1 : LEEMAN Magali
# (558) Opération de saisie terminée pour 1 : LEMPEN Blaise
# (559) Opération de saisie terminée pour 1 : LENOIR Alain
# (560) Opération de saisie terminée pour 1 : LERESCHE Michel
# (561) Opération de saisie terminée pour 1 : LERESCHE Séverine
# (562) Opération de saisie terminée pour 1 : LEROYER Michelie
# (563) Opération de saisie terminée pour 1 : LEU Sylvia
# (564) Opération de saisie terminée pour 1 : LEUBA de ROUSSILLON Jacqueline
# (565) Opération de saisie terminée pour 1 : LEUBA Jean-François
# (566) Opération de saisie terminée pour 1 : LEUENBERGER Monique
# (567) Opération de saisie terminée pour 1 : LEUTENEGGER Jacques
# (568) Opération de saisie terminée pour 1 : LEYDET Robert
# (569) Opération de saisie terminée pour 1 : LEYLAZ Jean-Louis
# (570) Opération de saisie terminée pour 1 : LEYVRAZ Marc
# (571) Opération de saisie terminée pour 1 : LICHE Anne
# (572) Opération de saisie terminée pour 1 : LIENGME Pascal
# (573) Opération de saisie terminée pour 1 : LOGOZ Roger-Charles
# (574) Opération de saisie terminée pour 1 : LOPEZ ANGLADA Luis
# (575) Opération de saisie terminée pour 1 : LOUTAU Marc
# (576) Opération de saisie terminée pour 1 : LOVIS-NEUENSCHWANDER Edith
# (577) Opération de saisie terminée pour 1 : MACKENZIE Compton
# (578) Opération de saisie terminée pour 1 : MAGGI Marie-Laurence
# (579) Opération de saisie terminée pour 1 : MAGNET Benoit
# (580) Opération de saisie terminée pour 1 : MAHAIM Natacha
# (581) Opération de saisie terminée pour 1 : MAIER René
# (582) Opération de saisie terminée pour 1 : MAILER Norman
# (583) Opération de saisie terminée pour 1 : MAILHET Jean
# (584) Opération de saisie terminée pour 1 : MALHERBE Guy
# (585) Opération de saisie terminée pour 1 : MALYE Jean
# (586) Opération de saisie terminée pour 1 : MAMIER Jean-Pierre
# (587) Opération de saisie terminée pour 1 : MANDRY Cornélia
# (588) Opération de saisie terminée pour 1 : MANSEAU Philippe
# (589) Opération de saisie terminée pour 1 : MANVILLE Paul
# (590) Opération de saisie terminée pour 1 : MANZ Esther
# (591) Opération de saisie terminée pour 1 : MARAT Noëlle
# (592) Opération de saisie terminée pour 1 : MARCEL Madeleine
# (593) Opération de saisie terminée pour 1 : MARÉ Pierre
# (594) Opération de saisie terminée pour 1 : MARGAREL Lee
# (595) Opération de saisie terminée pour 1 : MARGOT Louis
# (596) Opération de saisie terminée pour 1 : MARMILLOD Christiane
# (597) Opération de saisie terminée pour 1 : MARMITE David
# (598) Opération de saisie terminée pour 1 : MARQUERAT Ariane
# (599) Opération de saisie terminée pour 1 : MARTIN Jean-Georges
# (600) Opération de saisie terminée pour 1 : MARTIN Mady
# (601) Opération de saisie terminée pour 1 : MARTIN Marcel
# (602) Opération de saisie terminée pour 1 : MARTIN Paul
# (603) Opération de saisie terminée pour 1 : MARTIN-VOGEL Sophie-Hélène
# (604) Opération de saisie terminée pour 1 : MARTINELLI Punchate Adriana
# (605) Opération de saisie terminée pour 1 : MARTINET André
# (606) Opération de saisie terminée pour 1 : MARTINEZ de Martinez Héléna
# (607) Opération de saisie terminée pour 1 : MARTINEZ Rosa de Diego
# (608) Opération de saisie terminée pour 1 : MASNATA François
# (609) Opération de saisie terminée pour 1 : MASTROPAOLO Aurelio
# (610) Opération de saisie terminée pour 1 : MATHEY Marcel
# (611) Opération de saisie terminée pour 1 : MATTHEY Francis
# (612) Opération de saisie terminée pour 1 : MAURER-MAYOR Jacqueline
# (613) Opération de saisie terminée pour 1 : MAUROUX André
# (614) Opération de saisie terminée pour 1 : MAURUTTO Severino
# (615) Opération de saisie terminée pour 1 : MAYER Roman
# (616) Opération de saisie terminée pour 1 : MAYER Yvette
# (617) Opération de saisie terminée pour 1 : MAYOR Patrick
# (618) Opération de saisie terminée pour 1 : MAZLIAH Arlette
# (619) Opération de saisie terminée pour 1 : MCCAULEN Gross Ellen
# (620) Opération de saisie terminée pour 1 : MEELEN Gabrielle
# (621) Opération de saisie terminée pour 1 : MEGROZ François
# (622) Opération de saisie terminée pour 1 : MEISTER Frank
# (623) Opération de saisie terminée pour 1 : MELL Gérard
# (624) Opération de saisie terminée pour 1 : MENDEL Gérard
# (625) Opération de saisie terminée pour 1 : MENÉTREY Anne-Catherine
# (626) Opération de saisie terminée pour 1 : MENÉTREY François
# (627) Opération de saisie terminée pour 1 : MENÉTREY-LACROIX Liliane
# (628) Opération de saisie terminée pour 1 : MERCIER Nicole
# (629) Opération de saisie terminée pour 1 : MERCIER Pierre
# (630) Opération de saisie terminée pour 1 : MERCIER-CAMPICHE Marianne
# (631) Opération de saisie terminée pour 1 : METTRA Claude
# (632) Opération de saisie terminée pour 1 : MEURET Renée
# (633) Opération de saisie terminée pour 1 : MEYER Jeanine
# (634) Opération de saisie terminée pour 1 : MEYLAN André
# (635) Opération de saisie terminée pour 1 : MEYLAN Maurice
# (636) Opération de saisie terminée pour 1 : MEYLAN Pascal
# (637) Opération de saisie terminée pour 1 : MEYLAN Raymond
# (638) Opération de saisie terminée pour 1 : MEYRAT Gilbert
# (639) Opération de saisie terminée pour 1 : MEYRIN François
# (640) Opération de saisie terminée pour 1 : MEYROUD Tali
# (641) Opération de saisie terminée pour 1 : MIELE Giuseppe
# (642) Opération de saisie terminée pour 1 : MIÉVILLE Henri
# (643) Opération de saisie terminée pour 1 : MIKHAÏLO Marie-Christine
# (644) Opération de saisie terminée pour 1 : MININE Michel
# (645) Opération de saisie terminée pour 1 : MINT Franklin
# (646) Opération de saisie terminée pour 1 : MIZRAHI Maurice
# (647) Opération de saisie terminée pour 1 : MOLLES Christiane
# (648) Opération de saisie terminée pour 1 : MOLLES Ellen
# (649) Opération de saisie terminée pour 1 : MOLLY Bluette
# (650) Opération de saisie terminée pour 1 : MONARD Javier
# (651) Opération de saisie terminée pour 1 : MONASTIER Hélène
# (652) Opération de saisie terminée pour 1 : MONDOR Henry
# (653) Opération de saisie terminée pour 1 : MONNARD Jean
# (654) Opération de saisie terminée pour 1 : MONNEY Martine
# (655) Opération de saisie terminée pour 1 : MONNIER Guy
# (656) Opération de saisie terminée pour 1 : MONNIER Jacques
# (657) Opération de saisie terminée pour 1 : MONTANDON Judith
# (658) Opération de saisie terminée pour 1 : MONTANDON Monique-Arianne
# (659) Opération de saisie terminée pour 1 : MONTMOLLIN Jean-François de
# (660) Opération de saisie terminée pour 1 : MORARD Brigitte
# (661) Opération de saisie terminée pour 1 : MOREAU Jacques
# (662) Opération de saisie terminée pour 1 : MOREL Fernand
# (663) Opération de saisie terminée pour 1 : MOREL-PACHE Marion
# (664) Opération de saisie terminée pour 1 : MORET Jean-Claude
# (665) Opération de saisie terminée pour 1 : MORIER-GENOUD Gérald
# (666) Opération de saisie terminée pour 1 : MOROSOLI Régine
# (667) Opération de saisie terminée pour 1 : MOTTET Rose-Marie
# (668) Opération de saisie terminée pour 1 : MOTTURA Bettina
# (669) Opération de saisie terminée pour 1 : MOUFILLE Catherine de
# (670) Opération de saisie terminée pour 1 : MOUREL Claude
# (671) Opération de saisie terminée pour 1 : MOUROUX Charles
# (672) Opération de saisie terminée pour 1 : MOUSSON Georges
# (673) Opération de saisie terminée pour 1 : MOZER Hélène
# (674) Opération de saisie terminée pour 1 : MULLER Liane
# (675) Opération de saisie terminée pour 1 : MULLER-BREIL Paul
# (676) Opération de saisie terminée pour 1 : MURET Philibert
# (677) Opération de saisie terminée pour 1 : MURISET Lionel
# (678) Opération de saisie terminée pour 1 : MURITH Jean-Daniel
# (679) Opération de saisie terminée pour 1 : MURSET Daniel
# (680) Opération de saisie terminée pour 1 : MURY Jean
# (681) Opération de saisie terminée pour 1 : MUSSARD Alex
# (682) Opération de saisie terminée pour 1 : NABHOLZ Peter
# (683) Opération de saisie terminée pour 1 : NAEDTS Bernadette
# (684) Opération de saisie terminée pour 1 : NAEGELE Richard
# (685) Opération de saisie terminée pour 1 : NAVILLE Pierre
# (686) Opération de saisie terminée pour 1 : NEUENSCHWANDER Georges
# (687) Opération de saisie terminée pour 1 : NEUMANN Maya
# (688) Opération de saisie terminée pour 1 : NEYMARK Michel
# (689) Opération de saisie terminée pour 1 : NEYROUD Marc
# (690) Opération de saisie terminée pour 1 : NEYROUD Tali
# (691) Opération de saisie terminée pour 1 : NICOLA Monique
# (692) Opération de saisie terminée pour 1 : NICOLE Robert
# (693) Opération de saisie terminée pour 1 : NICOLET Jean-Claude
# (694) Opération de saisie terminée pour 1 : NICOULIN Maurice
# (695) Opération de saisie terminée pour 1 : NORDMANN-ZIMMERMANN Ursula
# (696) Opération de saisie terminée pour 1 : NOTH Myriam
# (697) Opération de saisie terminée pour 1 : NOTHOMB Simon-Pierre
# (698) Opération de saisie terminée pour 1 : NOTZ Edgar
# (699) Opération de saisie terminée pour 1 : NOVA Madeleine
# (700) Opération de saisie terminée pour 1 : OBER Didier
# (701) Opération de saisie terminée pour 1 : OBERSON Jean-Paul
# (702) Opération de saisie terminée pour 1 : OCHSENBEIN Claude
# (703) Opération de saisie terminée pour 1 : OKLAHOMA Norman
# (704) Opération de saisie terminée pour 1 : OULD-AMER Alain
# (705) Opération de saisie terminée pour 1 : OULHI Giovanni
# (706) Opération de saisie terminée pour 1 : PACE D’ARCOS Joaquim
# (707) Opération de saisie terminée pour 1 : PACHE René
# (708) Opération de saisie terminée pour 1 : PACHOUD Jean-Christophe
# (709) Opération de saisie terminée pour 1 : PAHUD Henri
# (710) Opération de saisie terminée pour 1 : PAHUD Jacques
# (711) Opération de saisie terminée pour 1 : PANCHAUD Isabelle
# (712) Opération de saisie terminée pour 1 : PANCIERA Giuseppe
# (713) Opération de saisie terminée pour 1 : PAPILLOUD Sabin
# (714) Opération de saisie terminée pour 1 : PAQUIER Jean-Paul
# (715) Opération de saisie terminée pour 1 : PARATTE Henri-Dominique
# (716) Opération de saisie terminée pour 1 : PARISEL Marc
# (717) Opération de saisie terminée pour 1 : PASCHE Bernard
# (718) Opération de saisie terminée pour 1 : PASTRE Geneviève
# (719) Opération de saisie terminée pour 1 : PAVILLARD Simone
# (720) Opération de saisie terminée pour 1 : PAYOT François-A.
# (721) Opération de saisie terminée pour 1 : PAYOT Pierre
# (722) Opération de saisie terminée pour 1 : PEARSON Norman
# (723) Opération de saisie terminée pour 1 : PELAT Jacques
# (724) Opération de saisie terminée pour 1 : PELET-MANGÉ Arlette
# (725) Opération de saisie terminée pour 1 : PEREY Claude
# (726) Opération de saisie terminée pour 1 : PERRENOUD Marc
# (727) Opération de saisie terminée pour 1 : PERRET Gaston
# (728) Opération de saisie terminée pour 1 : PERRET Pierre
# (778) Opération de saisie terminée pour 1 : RADECKE Kurt
# (779) Opération de saisie terminée pour 1 : RANC Catherine
# (780) Opération de saisie terminée pour 1 : RAPP Georges
# (781) Opération de saisie terminée pour 1 : RAPP Jean-Marc
# (782) Opération de saisie terminée pour 1 : RAVETON Roland
# (783) Opération de saisie terminée pour 1 : RAYMOND Valentin
# (784) Opération de saisie terminée pour 1 : REEVES Chris
# (785) Opération de saisie terminée pour 1 : REGAMEY Pierrette
# (786) Opération de saisie terminée pour 1 : REGENASS René
# (787) Opération de saisie terminée pour 1 : REICH Max
# (788) Opération de saisie terminée pour 1 : REICHEN Charles-Albert
# (789) Opération de saisie terminée pour 1 : RENAUD Jacqueline
# (790) Opération de saisie terminée pour 1 : RENAUD Jean-Denis
# (791) Opération de saisie terminée pour 1 : RENEVEY-OLIVIER Corine
# (792) Opération de saisie terminée pour 1 : RENFER Jacques
# (793) Opération de saisie terminée pour 1 : RENFER Marcel
# (794) Opération de saisie terminée pour 1 : RENFER-BERTHOUD Germaine
# (795) Opération de saisie terminée pour 1 : REY Gäetane
# (796) Opération de saisie terminée pour 1 : REY Jacques
# (797) Opération de saisie terminée pour 1 : REY Jos
# (798) Opération de saisie terminée pour 1 : REYMAND Pierre-Antoine
# (799) Opération de saisie terminée pour 1 : REYMOND Lise
# (800) Opération de saisie terminée pour 1 : REYMOND Mireille
# (801) Opération de saisie terminée pour 1 : REYMOND Pierre
# (802) Opération de saisie terminée pour 1 : RIBER Jean-Pierre
# (803) Opération de saisie terminée pour 1 : RIBET Liliane
# (804) Opération de saisie terminée pour 1 : RICHARD Bernadette
# (805) Opération de saisie terminée pour 1 : RICHARD Frédy
# (806) Opération de saisie terminée pour 1 : RIEUNEAU Maurice
# (807) Opération de saisie terminée pour 1 : RILLATTE Cécile
# (808) Opération de saisie terminée pour 1 : RITTENER André
# (809) Opération de saisie terminée pour 1 : RIVIER Françoise
# (810) Opération de saisie terminée pour 1 : ROCH Nadia
# (811) Opération de saisie terminée pour 1 : ROCHAT Charles
# (812) Opération de saisie terminée pour 1 : ROCHAT François
# (813) Opération de saisie terminée pour 1 : ROCHAT Louisa
# (814) Opération de saisie terminée pour 1 : ROCHAT Philippe
# (815) Opération de saisie terminée pour 1 : ROCHÉ Claude
# (816) Opération de saisie terminée pour 1 : ROCHÉ François
# (817) Opération de saisie terminée pour 1 : ROCHET Daniele
# (818) Opération de saisie terminée pour 1 : ROGER Jean-Louis
# (819) Opération de saisie terminée pour 1 : ROHR Laurence
# (820) Opération de saisie terminée pour 1 : ROHRER Christianne
# (821) Opération de saisie terminée pour 1 : ROHRER Robin
# (822) Opération de saisie terminée pour 1 : ROLLER Erich
# (823) Opération de saisie terminée pour 1 : ROLLIER Rita
# (824) Opération de saisie terminée pour 1 : ROMIRO Carlo
# (825) Opération de saisie terminée pour 1 : ROSSEL Alain
# (826) Opération de saisie terminée pour 1 : ROSSELET André
# (827) Opération de saisie terminée pour 1 : ROSSET Jan
# (828) Opération de saisie terminée pour 1 : ROSSET-MONNIER Carole
# (829) Opération de saisie terminée pour 1 : ROSSIER Cédric
# (830) Opération de saisie terminée pour 1 : ROSSIER Francis
# (831) Opération de saisie terminée pour 1 : ROSSIER Gertrude
# (832) Opération de saisie terminée pour 1 : ROSSIER-DUTOIT Anne-Bernardin
# (833) Opération de saisie terminée pour 1 : ROTHEN Gisèle
# (834) Opération de saisie terminée pour 1 : ROTMAN-OVERNEY Michel
# (835) Opération de saisie terminée pour 1 : ROTTENBERG Hertha
# (836) Opération de saisie terminée pour 1 : ROULIER Marguerite
# (837) Opération de saisie terminée pour 1 : ROUSSEAU André
# (838) Opération de saisie terminée pour 1 : ROUSSEUIL Jean-Daniel
# (839) Opération de saisie terminée pour 1 : RUDZAN Etienne
# (840) Opération de saisie terminée pour 1 : RUMPF Louis
# (841) Opération de saisie terminée pour 1 : RUPP Alfred
# (842) Opération de saisie terminée pour 1 : RYSEN Emmanuelle
# (843) Opération de saisie terminée pour 1 : SADEGLI Hassan
# (844) Opération de saisie terminée pour 1 : SAHAGUN Carlos
# (845) Opération de saisie terminée pour 1 : SAHY Pascale
# (846) Opération de saisie terminée pour 1 : SALATI Vinicio
# (847) Opération de saisie terminée pour 1 : SALIS Bruno
# (848) Opération de saisie terminée pour 1 : SALIS Yves
# (849) Opération de saisie terminée pour 1 : SALMAND Marie-France
# (850) Opération de saisie terminée pour 1 : SALMOND Marie-France
# (851) Opération de saisie terminée pour 1 : SAMMALI Jacqueline
# (852) Opération de saisie terminée pour 1 : SANCEY Yves
# (853) Opération de saisie terminée pour 1 : SANCHES Dominique-Jean
# (854) Opération de saisie terminée pour 1 : SANTSCHI Pierre
# (855) Opération de saisie terminée pour 1 : SAUGHLER James
# (856) Opération de saisie terminée pour 1 : SAUGY Roger
# (857) Opération de saisie terminée pour 1 : SAYMAL Jacques
# (858) Opération de saisie terminée pour 1 : SCAIOLA Emmanuel
# (859) Opération de saisie terminée pour 1 : SCARPATETTI Beat Von
# (860) Opération de saisie terminée pour 1 : SCHEIDEGGER Quinche Louise
# (861) Opération de saisie terminée pour 1 : SCHEIWILLER Vanni
# (862) Opération de saisie terminée pour 1 : SCHEUERMEIER Paul
# (863) Opération de saisie terminée pour 1 : SCHILT Jean-Jacques
# (864) Opération de saisie terminée pour 1 : SCHILTKNECHT Estelle
# (865) Opération de saisie terminée pour 1 : SCHILTKNECHT Wilfred
# (866) Opération de saisie terminée pour 1 : SCHLINGEL Michel
# (867) Opération de saisie terminée pour 1 : SCHLOZER Danielle
# (868) Opération de saisie terminée pour 1 : SCHLÜMPERLI Martine
# (869) Opération de saisie terminée pour 1 : SCHLUNEGGER-REICH Joy Marianne
# (870) Opération de saisie terminée pour 1 : SCHMID Rolf
# (871) Opération de saisie terminée pour 1 : SCHMID-GIROUD Nadine
# (872) Opération de saisie terminée pour 1 : SCHMITT Ariane
# (873) Opération de saisie terminée pour 1 : SCHNEIDER Antoinette
# (874) Opération de saisie terminée pour 1 : SCHNOERING Philippe
# (875) Opération de saisie terminée pour 1 : SCHNORF Mireille
# (876) Opération de saisie terminée pour 1 : SCHNURRENBERGER Izabel
# (877) Opération de saisie terminée pour 1 : SCHOCH Ulrich
# (878) Opération de saisie terminée pour 1 : SCHON Baptiste
# (879) Opération de saisie terminée pour 1 : SCHOPFER Jacques
# (880) Opération de saisie terminée pour 1 : SCHORI Gilberte
# (881) Opération de saisie terminée pour 1 : SCHROFF M (ancien élève)
# (882) Opération de saisie terminée pour 1 : SCHULER Pierre
# (883) Opération de saisie terminée pour 1 : SCHULIGER Fabienne
# (884) Opération de saisie terminée pour 1 : SCHUMACHER Henri von
# (885) Opération de saisie terminée pour 1 : SCHWAAB Jean-Jacques
# (886) Opération de saisie terminée pour 1 : SCHWAB Anne
# (887) Opération de saisie terminée pour 1 : SCHWEIZER Rudi
# (888) Opération de saisie terminée pour 1 : SCIBOZ Véronique
# (889) Opération de saisie terminée pour 1 : SECRETAN Claude
# (890) Opération de saisie terminée pour 1 : SERREAU Geneviève
# (891) Opération de saisie terminée pour 1 : SIA Edizioni
# (892) Opération de saisie terminée pour 1 : SIDLER Louis
# (893) Opération de saisie terminée pour 1 : SIMÉON Jean-Pierre
# (894) Opération de saisie terminée pour 1 : SIMON Jean-Charles
# (895) Opération de saisie terminée pour 1 : SIMON Robert
# (896) Opération de saisie terminée pour 1 : SINGER Christian Van
# (897) Opération de saisie terminée pour 1 : SOLLBERGER Charles
# (898) Opération de saisie terminée pour 1 : SPALTENSTEIN François
# (899) Opération de saisie terminée pour 1 : SPASIĆ Miroslava
# (900) Opération de saisie terminée pour 1 : STÁNESCU Flore
# (901) Opération de saisie terminée pour 1 : STARK-TOWLSON Helen
# (902) Opération de saisie terminée pour 1 : STAUB Martin
# (903) Opération de saisie terminée pour 1 : STAUFFACHER Wenner
# (904) Opération de saisie terminée pour 1 : STAUFFER Gilles
# (905) Opération de saisie terminée pour 1 : STEHLI Jean-Claude
# (906) Opération de saisie terminée pour 1 : STEINEGGER Jean
# (907) Opération de saisie terminée pour 1 : STEINER Christine
# (908) Opération de saisie terminée pour 1 : STOCCO Patrick
# (909) Opération de saisie terminée pour 1 : STOLL Jean-Martin
# (910) Opération de saisie terminée pour 1 : STUDER-MÜLLER Marie-Françoise
# (911) Opération de saisie terminée pour 1 : SUGNAUX André
# (912) Opération de saisie terminée pour 1 : SULKY Charles
# (913) Opération de saisie terminée pour 1 : SURER Jean-Marie (docteur)
# (914) Opération de saisie terminée pour 1 : SUTER François
# (915) Opération de saisie terminée pour 1 : SUTTER Anna
# (916) Opération de saisie terminée pour 1 : TA-KAN Lo
# (917) Opération de saisie terminée pour 1 : TABIN Jean-Pierre
# (918) Opération de saisie terminée pour 1 : TAILLENS Violette
# (919) Opération de saisie terminée pour 1 : TANNER Jean-Marie
# (920) Opération de saisie terminée pour 1 : TASSIR Goun
# (921) Opération de saisie terminée pour 1 : TAUBERT Marianne
# (922) Opération de saisie terminée pour 1 : TCHICALOFF Michel
# (923) Opération de saisie terminée pour 1 : TECCHI Bonaventura
# (924) Opération de saisie terminée pour 1 : TEMKINE Raymonde
# (925) Opération de saisie terminée pour 1 : TENCHIO Licinia
# (926) Opération de saisie terminée pour 1 : TERCIER Judith
# (927) Opération de saisie terminée pour 1 : TEYSSEIRE Pierre
# (928) Opération de saisie terminée pour 1 : THEURILLAT Anne-Lise
# (929) Opération de saisie terminée pour 1 : THIBAUD-JACCARD Marianne
# (930) Opération de saisie terminée pour 1 : THOMANN André
# (931) Opération de saisie terminée pour 1 : THORENS Joël
# (932) Opération de saisie terminée pour 1 : THURER Joël
# (933) Opération de saisie terminée pour 1 : TIERCY Denise
# (934) Opération de saisie terminée pour 1 : TIKOU-ROLLIER Samuel
# (935) Opération de saisie terminée pour 1 : TISSOT Pierre-Alain
# (936) Opération de saisie terminée pour 1 : TOBLER Brigitte
# (937) Opération de saisie terminée pour 1 : TORIEL Eric
# (938) Opération de saisie terminée pour 1 : TORRANCINTA Claude
# (939) Opération de saisie terminée pour 1 : TRÉMISEAU Alain
# (940) Opération de saisie terminée pour 1 : TREPEY Erice
# (941) Opération de saisie terminée pour 1 : TREYVAUD Anne-Marie
# (942) Opération de saisie terminée pour 1 : TRILLING Lionel
# (943) Opération de saisie terminée pour 1 : TRIPOD Pierre
# (944) Opération de saisie terminée pour 1 : TSENG Beauson
# (945) Opération de saisie terminée pour 1 : TSI-SIANG Lo
# (946) Opération de saisie terminée pour 1 : TSIOLIS Anna
# (947) Opération de saisie terminée pour 1 : TULIS Marianne
# (948) Opération de saisie terminée pour 1 : TUSCHER Felix
# (949) Opération de saisie terminée pour 1 : UGHETTO André
# (950) Opération de saisie terminée pour 1 : ULDRY Carine
# (951) Opération de saisie terminée pour 1 : ULHER Fred
# (952) Opération de saisie terminée pour 1 : URBAIN Jacques
# (953) Opération de saisie terminée pour 1 : URFER-BESSINE Simone
# (954) Opération de saisie terminée pour 1 : VALBERT Gérard
# (955) Opération de saisie terminée pour 1 : VALERI Diego
# (956) Opération de saisie terminée pour 1 : VALLECCHI Attilio
# (957) Opération de saisie terminée pour 1 : VALLON Bernard
# (958) Opération de saisie terminée pour 1 : VALVERDE José-Maria
# (959) Opération de saisie terminée pour 1 : VANNIER Angèle
# (960) Opération de saisie terminée pour 1 : VARONIER Michèle
# (961) Opération de saisie terminée pour 1 : VAUCHER Philippe
# (962) Opération de saisie terminée pour 1 : VAUDOU François
# (963) Opération de saisie terminée pour 1 : VAUTIER Violette
# (964) Opération de saisie terminée pour 1 : VEDRY Christine
# (965) Opération de saisie terminée pour 1 : VEILLARD Sylvie
# (966) Opération de saisie terminée pour 1 : VERDAN André
# (967) Opération de saisie terminée pour 1 : VERDAN Claude
# (968) Opération de saisie terminée pour 1 : VERDAN Jean-Paul
# (969) Opération de saisie terminée pour 1 : VERDON Anne
# (970) Opération de saisie terminée pour 1 : VERTESI Niklaus
# (971) Opération de saisie terminée pour 1 : VESPER Noël
# (972) Opération de saisie terminée pour 1 : VETTORI Vittorio
# (973) Opération de saisie terminée pour 1 : VIALLANEIX Paul
# (974) Opération de saisie terminée pour 1 : VIARD Jacques
# (975) Opération de saisie terminée pour 1 : VIDOZ René
# (976) Opération de saisie terminée pour 1 : VILLIGER Kaspar
# (977) Opération de saisie terminée pour 1 : VINCENT Christiane
# (978) Opération de saisie terminée pour 1 : VIREDAZ Charlotte
# (979) Opération de saisie terminée pour 1 : VITTOZ Françoise
# (980) Opération de saisie terminée pour 1 : VOEGELI Christine
# (981) Opération de saisie terminée pour 1 : VOELLZE André
# (982) Opération de saisie terminée pour 1 : VOGEL Bernard
# (983) Opération de saisie terminée pour 1 : VOÏTA Denise Marie
# (984) Opération de saisie terminée pour 1 : VONABURG Stéphanie
# (985) Opération de saisie terminée pour 1 : VOUGA Jacqueline
# (986) Opération de saisie terminée pour 1 : VRILLON Pierre-François
# (987) Opération de saisie terminée pour 1 : VUILLÈME Gilbert
# (988) Opération de saisie terminée pour 1 : VUILLÈME Jean-Bernard
# (989) Opération de saisie terminée pour 1 : VUILLEUMIER Marc
# (990) Opération de saisie terminée pour 1 : VUITHIER Alain
# (991) Opération de saisie terminée pour 1 : WAHLI Jean-Jacques
# (992) Opération de saisie terminée pour 1 : WALKER Pierre
# (993) Opération de saisie terminée pour 1 : WALTHER Jacques
# (994) Opération de saisie terminée pour 1 : WANNER Louise
# (995) Opération de saisie terminée pour 1 : WARREN PEN Robert
# (996) Opération de saisie terminée pour 1 : WASSERFALLER Anne-Marie
# (997) Opération de saisie terminée pour 1 : WEBER Beat
# (998) Opération de saisie terminée pour 1 : WEBER Franz
# (999) Opération de saisie terminée pour 1 : WEBER PERRET Myriam
# (1000) Opération de saisie terminée pour 1 : WEIDMANN Jean-Pierre
# (1001) Opération de saisie terminée pour 1 : WELTSTEIN Irène
# (1002) Opération de saisie terminée pour 1 : WERNER Eric
# (1003) Opération de saisie terminée pour 1 : WETTSTEIN Laurette
# (1004) Opération de saisie terminée pour 1 : WEYRAUCH Wolfgang
# (1005) Opération de saisie terminée pour 1 : WIDMANN Cordula
# (1006) Opération de saisie terminée pour 1 : WIDMER Gabrielle
# (1007) Opération de saisie terminée pour 1 : WIGGLI Janine
# (1008) Opération de saisie terminée pour 1 : WILBUR Richard
# (1009) Opération de saisie terminée pour 1 : WILHEM Daniel
# (1010) Opération de saisie terminée pour 1 : WILKER Gertrud
# (1011) Opération de saisie terminée pour 1 : WILKINS Kay
# (1012) Opération de saisie terminée pour 1 : WINTER Michel
# (1013) Opération de saisie terminée pour 1 : YECHOUROUN Claude
# (1014) Opération de saisie terminée pour 1 : YERSIN Jean-Robert
# (1015) Opération de saisie terminée pour 1 : YU-LIEH Chi
# (1016) Opération de saisie terminée pour 1 : ZAHER Patrick
# (1017) Opération de saisie terminée pour 1 : ZANGGER-PEITREQUIN Denise
# (1018) Opération de saisie terminée pour 1 : ZAUGG-PRATO Luisa
# (1019) Opération de saisie terminée pour 1 : ZEFFER Jean
# (1020) Opération de saisie terminée pour 1 : ZENAINI Nour-Eddine
# (1021) Opération de saisie terminée pour 1 : ZENGER Henri
# (1022) Opération de saisie terminée pour 1 : ZERMATTEN Monique
# (1023) Opération de saisie terminée pour 1 : ZIEGLEBNER Dieter
# (1024) Opération de saisie terminée pour 1 : ZISYADIS Josef
# (1025) Opération de saisie terminée pour 1 : GUÉNIAT Cinzia
# (1026) Opération de saisie terminée pour 1 : GU
# (1027) Opération de saisie terminée pour 1 : SUTTER Noémie
# (1028) Opération de saisie terminée pour 1 : TOURNEBIZE Jean-Marie
# (1029) Opération de saisie terminée pour 1 : FUCHS Janine
# (1030) Opération de saisie terminée pour 1 : HERBERICHS Gérard
# (1031) Opération de saisie terminée pour 1 : MARY François
# (1032) Opération de saisie terminée pour 1 : DRUINOT Patrick
# (1033) Opération de saisie terminée pour 1 : GIACOLETTO Simone
# (1034) Opération de saisie terminée pour 1 : HERCOURT Jean
# (1035) Opération de saisie terminée pour 1 : DUCRET Jean-Daniel
# (1036) Opération de saisie terminée pour 1 : CARROT Antoine
# (1037) Opération de saisie terminée pour 1 : KRIVANS Katia
# (1038) Opération de saisie terminée pour 1 : DAVI Hans-Leopold
# (1039) Opération de saisie terminée pour 1 : GAILLARD-DAUCOURT Elisabeth
# (1040) Opération de saisie terminée pour 1 : OBERMÜLLER Klara
# (1041) Opération de saisie terminée pour 1 : GRIVEL Jean-Claude
# (1042) Opération de saisie terminée pour 1 : ZWAHLEN-MONCAIRE Monique
# (1043) Opération de saisie terminée pour 1 : BONN Annette
# (1044) Opération de saisie terminée pour 1 : CHEKCHOUK Rachid
# (1045) Opération de saisie terminée pour 1 : MONNIER-RABALL Jacques
# (1046) Opération de saisie terminée pour 1 : DUPONT Régis
# (1047) Opération de saisie terminée pour 1 : HENRIOD Gil
# (1048) Opération de saisie terminée pour 1 : AZAD Catherine
# (1049) Opération de saisie terminée pour 1 : KERNS Jacques
# (1050) Opération de saisie terminée pour 1 : ROMERIO Alain
# (1051) Opération de saisie terminée pour 1 : BAEZNER Réjane
# (1052) Opération de saisie terminée pour 1 : BIOLAZ Jean-Daniel
# (1053) Opération de saisie terminée pour 1 : ARMA Paul
# (1054) Opération de saisie terminée pour 1 : LEUBA Serge-Olivier
# (1055) Opération de saisie terminée pour 1 : KELLER Christiane
# (1056) Opération de saisie terminée pour 1 : HENNART Marcel
# (1057) Opération de saisie terminée pour 1 : SCHÄRER Maya
# (1058) Opération de saisie terminée pour 1 : CLOUX Pierre
# (1059) Opération de saisie terminée pour 1 : SAINT-LÔ Michèle

# %% [markdown]
# ## LANCEMENT DES FONCTIONS

# %%
# ETAPE 1
driver = Browser()
access_atom(driver)

# ETAPE 2
csv_path = '01_noticesACompleter.csv'
autorities = extract_autorite(csv_path)

# ETAPE 3
csv_path = '01_noticesACompleter.csv'
autorites_url = open_autorites(csv_path)

# ETAPE 4
modify_autorites(driver, autorities, autorites_url)
